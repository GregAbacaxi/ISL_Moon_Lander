# %%
import gymnasium as gym
from stable_baselines3 import PPO

# %%
env = gym.make('LunarLander-v3', render_mode="human")
model = PPO('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=150000)
model.save('ppo_lunarlander')
env = model.get_env()
obs = env.reset()

env = model.get_env()
obs = env.reset()

for _ in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    if done:
        obs = env.reset()
env.close()
# Out:
# <frozen importlib._bootstrap>:491: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /mnt/nvme/cloned_repositories/isl_moon_lander/venv/lib/python3.14/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98       |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    fps             | 48       |
# |    iterations      | 1        |
# |    time_elapsed    | 42       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.8        |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 2           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007292656 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00118    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 593         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00874    |
# |    value_loss           | 1.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.9        |
# |    ep_rew_mean          | -158        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 3           |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006974111 |
# |    clip_fraction        | 0.0062      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0407     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 745         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.4        |
# |    ep_rew_mean          | -173        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 4           |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014687318 |
# |    clip_fraction        | 0.0921      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0024      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 315         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 718         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.9        |
# |    ep_rew_mean          | -169        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 5           |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008512394 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.000868   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 652         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00586    |
# |    value_loss           | 1.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -157        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 6           |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010094353 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0631     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 322         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 626         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 107         |
# |    ep_rew_mean          | -145        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 7           |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009246771 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00528    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 401         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00691    |
# |    value_loss           | 540         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 8           |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013023159 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.000677   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 250         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 533         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 9           |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011518065 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -9.3e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 138         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 302         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | -128        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 10          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013295335 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -9.75e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 160         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 342         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 11          |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011307094 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | -0.0116     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 243         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00366    |
# |    value_loss           | 632         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 12          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010631042 |
# |    clip_fraction        | 0.0239      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | -0.000151   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 110         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00545    |
# |    value_loss           | 332         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | -94.7       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 13          |
# |    time_elapsed         | 553         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005922408 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.000993    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 171         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 273         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | -84.5        |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 14           |
# |    time_elapsed         | 595          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0054530827 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | -0.000809    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 194          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00755     |
# |    value_loss           | 414          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -85.3       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 15          |
# |    time_elapsed         | 637         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006041836 |
# |    clip_fraction        | 0.0142      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.0575      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 102         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 304         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | -87.5       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 16          |
# |    time_elapsed         | 679         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010434544 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0588      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 109         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00903    |
# |    value_loss           | 199         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | -83.3        |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 17           |
# |    time_elapsed         | 721          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0071235355 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 115          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00532     |
# |    value_loss           | 278          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 216         |
# |    ep_rew_mean          | -84.3       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 18          |
# |    time_elapsed         | 764         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005475866 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 45          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 231         |
# |    ep_rew_mean          | -82.1       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 19          |
# |    time_elapsed         | 806         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009321025 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.179       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00903    |
# |    value_loss           | 164         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 249          |
# |    ep_rew_mean          | -80.1        |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 20           |
# |    time_elapsed         | 848          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0069533484 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.9         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00848     |
# |    value_loss           | 115          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 258         |
# |    ep_rew_mean          | -75.1       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 21          |
# |    time_elapsed         | 890         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016491298 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.2        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 66.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | -74.8       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 22          |
# |    time_elapsed         | 932         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008023676 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.7        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00698    |
# |    value_loss           | 180         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 288          |
# |    ep_rew_mean          | -72          |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 23           |
# |    time_elapsed         | 974          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0052231755 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38           |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00546     |
# |    value_loss           | 110          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 310          |
# |    ep_rew_mean          | -69.5        |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 24           |
# |    time_elapsed         | 1016         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0077250134 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.5         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00556     |
# |    value_loss           | 59.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | -67.4       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 25          |
# |    time_elapsed         | 1059        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008234661 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42          |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | -63.7       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 26          |
# |    time_elapsed         | 1101        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008068789 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0072     |
# |    value_loss           | 91.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 350          |
# |    ep_rew_mean          | -55.6        |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 27           |
# |    time_elapsed         | 1143         |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0077528832 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.967       |
# |    explained_variance   | 0.48         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.6         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 92.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 365         |
# |    ep_rew_mean          | -48.2       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 28          |
# |    time_elapsed         | 1185        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017525349 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 381         |
# |    ep_rew_mean          | -42.7       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 29          |
# |    time_elapsed         | 1227        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.012047013 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.6        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00943    |
# |    value_loss           | 149         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | -36.6       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 30          |
# |    time_elapsed         | 1269        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008511892 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.85       |
# |    explained_variance   | 0.0883      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 165         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 411         |
# |    ep_rew_mean          | -26.7       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 31          |
# |    time_elapsed         | 1312        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.012073836 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | 0.0821      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 117         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00717    |
# |    value_loss           | 178         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 427          |
# |    ep_rew_mean          | -23.1        |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 32           |
# |    time_elapsed         | 1354         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0032651727 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.698       |
# |    explained_variance   | 0.0871       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 218          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 260          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 440          |
# |    ep_rew_mean          | -21          |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 33           |
# |    time_elapsed         | 1396         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0056744423 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.928       |
# |    explained_variance   | 0.00194      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0051      |
# |    value_loss           | 157          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 454         |
# |    ep_rew_mean          | -18         |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 34          |
# |    time_elapsed         | 1438        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008640542 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00512    |
# |    value_loss           | 176         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 466         |
# |    ep_rew_mean          | -12.4       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 35          |
# |    time_elapsed         | 1480        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005956357 |
# |    clip_fraction        | 0.0582      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.746      |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.3        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 124         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 483         |
# |    ep_rew_mean          | -3.87       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 36          |
# |    time_elapsed         | 1522        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004809666 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.1        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 93.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 501          |
# |    ep_rew_mean          | -3.2         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 37           |
# |    time_elapsed         | 1564         |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0065963534 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | 0.371        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.7         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 114          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 518          |
# |    ep_rew_mean          | -2.05        |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 38           |
# |    time_elapsed         | 1606         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0021275529 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.971       |
# |    explained_variance   | -0.0125      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.1         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 156          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 531         |
# |    ep_rew_mean          | 0.853       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 39          |
# |    time_elapsed         | 1649        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010811666 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.7        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 44.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 543         |
# |    ep_rew_mean          | 1.13        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 40          |
# |    time_elapsed         | 1691        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007796004 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | -0.0112     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00791    |
# |    value_loss           | 140         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 557         |
# |    ep_rew_mean          | 0.574       |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 41          |
# |    time_elapsed         | 1733        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004718001 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.0899      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 120         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 576        |
# |    ep_rew_mean          | 6.52       |
# | time/                   |            |
# |    fps                  | 48         |
# |    iterations           | 42         |
# |    time_elapsed         | 1775       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00778915 |
# |    clip_fraction        | 0.0388     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.91      |
# |    explained_variance   | 0.238      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.5       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00612   |
# |    value_loss           | 95.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 591        |
# |    ep_rew_mean          | 8.57       |
# | time/                   |            |
# |    fps                  | 48         |
# |    iterations           | 43         |
# |    time_elapsed         | 1817       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.00946698 |
# |    clip_fraction        | 0.0528     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.848     |
# |    explained_variance   | 0.187      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.29       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00328   |
# |    value_loss           | 59.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 606         |
# |    ep_rew_mean          | 11.5        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 44          |
# |    time_elapsed         | 1859        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008519352 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.974      |
# |    explained_variance   | 0.483       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.93        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 39          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 620         |
# |    ep_rew_mean          | 13.8        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 45          |
# |    time_elapsed         | 1901        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006205526 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 144         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00552    |
# |    value_loss           | 123         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 631         |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 46          |
# |    time_elapsed         | 1943        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005406863 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.31        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 42.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 652          |
# |    ep_rew_mean          | 23.8         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 47           |
# |    time_elapsed         | 1985         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0038039046 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.878       |
# |    explained_variance   | 0.592        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.56         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00396     |
# |    value_loss           | 67.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 668         |
# |    ep_rew_mean          | 23.2        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 48          |
# |    time_elapsed         | 2027        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005718776 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00905    |
# |    value_loss           | 71.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 674          |
# |    ep_rew_mean          | 24.8         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 49           |
# |    time_elapsed         | 2069         |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0071311747 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.978       |
# |    explained_variance   | -0.275       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.9         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00524     |
# |    value_loss           | 146          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 673          |
# |    ep_rew_mean          | 25.5         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 50           |
# |    time_elapsed         | 2111         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0038446381 |
# |    clip_fraction        | 0.0608       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.965       |
# |    explained_variance   | -0.891       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.35         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.000326     |
# |    value_loss           | 46.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 683          |
# |    ep_rew_mean          | 28.6         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 51           |
# |    time_elapsed         | 2153         |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0046781916 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.955       |
# |    explained_variance   | 0.382        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.39         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.000153     |
# |    value_loss           | 31.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 694         |
# |    ep_rew_mean          | 32.6        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 52          |
# |    time_elapsed         | 2195        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010469356 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.883      |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.04        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0072     |
# |    value_loss           | 15.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 705         |
# |    ep_rew_mean          | 31.2        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 53          |
# |    time_elapsed         | 2237        |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.008230064 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 30.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 718          |
# |    ep_rew_mean          | 31.9         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 54           |
# |    time_elapsed         | 2280         |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0062758764 |
# ...
# |    ep_len_mean          | 740          |
# |    ep_rew_mean          | 43.1         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 57           |
# |    time_elapsed         | 2406         |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0044843266 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.82        |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.65         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 65.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 742          |
# |    ep_rew_mean          | 48.7         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 58           |
# |    time_elapsed         | 2448         |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0044937152 |
# |    clip_fraction        | 0.055        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.887       |
# |    explained_variance   | 0.848        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.26         |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 35.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 751         |
# |    ep_rew_mean          | 53.4        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 59          |
# |    time_elapsed         | 2490        |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.007321419 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.927      |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.9         |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 34.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 751          |
# |    ep_rew_mean          | 57.1         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 60           |
# |    time_elapsed         | 2532         |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0031958418 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.888       |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.29         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 40           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 759         |
# |    ep_rew_mean          | 61.9        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 61          |
# |    time_elapsed         | 2574        |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.006305133 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.43        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 36.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 762         |
# |    ep_rew_mean          | 61.1        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 62          |
# |    time_elapsed         | 2616        |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.010026275 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.2        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 39.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 769         |
# |    ep_rew_mean          | 65.6        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 63          |
# |    time_elapsed         | 2658        |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.005301858 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | -0.0592     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30          |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 164         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 766         |
# |    ep_rew_mean          | 64.2        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 64          |
# |    time_elapsed         | 2700        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.004807699 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00371    |
# |    value_loss           | 68.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 765          |
# |    ep_rew_mean          | 65.4         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 65           |
# |    time_elapsed         | 2743         |
# |    total_timesteps      | 133120       |
# | train/                  |              |
# |    approx_kl            | 0.0063257325 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | 0.418        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 118          |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 103          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 770         |
# |    ep_rew_mean          | 66.2        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 66          |
# |    time_elapsed         | 2785        |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.016022962 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.832      |
# |    explained_variance   | 0.0709      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.4        |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.00717    |
# |    value_loss           | 94.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 776          |
# |    ep_rew_mean          | 70.7         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 67           |
# |    time_elapsed         | 2827         |
# |    total_timesteps      | 137216       |
# | train/                  |              |
# |    approx_kl            | 0.0037556165 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.824       |
# |    explained_variance   | 0.473        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.8         |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 95.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 779          |
# |    ep_rew_mean          | 69.7         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 68           |
# |    time_elapsed         | 2869         |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0122040585 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.93        |
# |    explained_variance   | 0.723        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.00687     |
# |    value_loss           | 48.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 783          |
# |    ep_rew_mean          | 68.9         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 69           |
# |    time_elapsed         | 2911         |
# |    total_timesteps      | 141312       |
# | train/                  |              |
# |    approx_kl            | 0.0032658912 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.796       |
# |    explained_variance   | 0.85         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.4         |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 36.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 783          |
# |    ep_rew_mean          | 71.8         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 70           |
# |    time_elapsed         | 2953         |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0045197876 |
# |    clip_fraction        | 0.0709       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.833       |
# |    explained_variance   | 0.842        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.2         |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00418     |
# |    value_loss           | 42.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 782          |
# |    ep_rew_mean          | 72.6         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 71           |
# |    time_elapsed         | 2996         |
# |    total_timesteps      | 145408       |
# | train/                  |              |
# |    approx_kl            | 0.0057798857 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.911       |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21           |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 34.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 774         |
# |    ep_rew_mean          | 74.6        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 72          |
# |    time_elapsed         | 3038        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.004351757 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.00271    |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 769         |
# |    ep_rew_mean          | 74.7        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 73          |
# |    time_elapsed         | 3080        |
# |    total_timesteps      | 149504      |
# | train/                  |             |
# |    approx_kl            | 0.006130731 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.81       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.7        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00387    |
# |    value_loss           | 36.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 756        |
# |    ep_rew_mean          | 75.5       |
# | time/                   |            |
# |    fps                  | 48         |
# |    iterations           | 74         |
# |    time_elapsed         | 3122       |
# |    total_timesteps      | 151552     |
# | train/                  |            |
# |    approx_kl            | 0.01403665 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.8       |
# |    explained_variance   | 0.812      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.2       |
# |    n_updates            | 730        |
# |    policy_gradient_loss | -0.0112    |
# |    value_loss           | 49.6       |
# ----------------------------------------
